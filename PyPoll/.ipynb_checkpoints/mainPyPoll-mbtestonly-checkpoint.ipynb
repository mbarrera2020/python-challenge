# %%
# main -- for python-challenge PyPoll
import os
import csv
import operator   # needed to make sort work

# %%
# setup path for input file location
# REMEMBER: remove '1test' from filename -- test data has < 100 rows including header
csvpath=os.path.join('Resources','election_data1test.csv')
csvpath
# Out:
# 'Resources\\election_data1test.csv'

# %%
# open & loop through the rows and get total votes by candidates

# create a 'unique' candidate list
candidate_unique = set()

with open(csvpath) as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    
    # Read the header row first (skip this step if there is row header)
    csv_header = next(csvreader)
    #print(f"CSV Header: {csv_header}")
            
    sort = sorted(csvreader, key=operator.itemgetter(2))
    
    # TEMP - diplay input file data
    for row in sort:
        #print(row)
        candidate_unique.add(row[2])

print (candidate_unique)
num_candidates = len(list(candidate_unique))
print ("# of candidates:", num_candidates)
# Out:
# {'Khan', "O'Tooley", 'Li', 'Correy'}
# # of candidates: 4

# %%
# convert the set to a list so the index can be referenced

# create candidate list & num votes list
candidate_lst = []

for i in candidate_unique:
    candidate_lst.append(i)

# sort the list of candidates    
# candidate_lst.sort()    
print ("This is the candidate list: ", candidate_lst)
print ()
print ("# of candidates: ", len(candidate_lst))
# Out:
# This is the candidate list:  ['Khan', "O'Tooley", 'Li', 'Correy']
#
# # of candidates:  4

# %%
# create poll data dictionary with candidate, votes, percent
votes_lst = [0]*len(candidate_lst)
percent_lst = [0]*len(candidate_lst)

#polldata = dict(zip(candidate_lst, votes_lst, percent_lst))

polldata = {
    "candidate_name": (candidate_lst),
    "candidate_votes": [0]*len(candidate_lst),
#"candidate_votes": (votes_lst),
    "percentage": (percent_lst)}

polldata
# Out:
# {'candidate_name': ['Khan', "O'Tooley", 'Li', 'Correy'],
#  'candidate_votes': [0, 0, 0, 0],
#  'percentage': [0, 0, 0, 0]}

# %%
# open & loop through the rows and get total votes by candidates

votes_c = 0
total_votes = 0

i = 0
n = num_candidates

print ("This is the candidate list: ", candidate_lst)
print ()

with open(csvpath) as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    
    # Read the header row first (skip this step if there is row header)
    csv_header = next(csvreader)
    print(f"CSV Header: {csv_header}")
    print()

    for row in csvreader:
        print ("Row read for processing is: ", row)
        print ()
        # set index for candidate list to 0
        y=0  
        print ("Candidate list index y value = ", y)
        print ()
        
        # check if candidate on the input file does not match the candidate on the candidate list
        # add 1 to the index until there is a match
        while (row[2]) != candidate_lst[y]:
            print ((row[2]), "!=", candidate_lst[y])
            print ()
            y = y+1
            print ("y counter = ", y)
            print("candidate_lst[y] is: ", candidate_lst[y])
            print()
            
        # candidate comparison matched!  
        # add the votes on the row to the votes list of the candidate
        print ("Candidate matched!")
        print ((row[2]), "=", candidate_lst[y])
        print ()
        
        
        # add votes of candidate to the votes_lst
        print ("Contents of votes list: ")
        print ()
        votes_lst
        votes_lst[y] = votes_lst[y] + 1
        
                           
        # add the votes to the grand total votes variable
        total_votes = total_votes + 1
        print ("Grand total votes = ", total_votes)
        print
               
        i = i + 1
                            
print (candidate_lst)
print ()
print (votes_lst)
# Out:
# This is the candidate list:  ['Khan', "O'Tooley", 'Li', 'Correy']
#
# CSV Header: ['Voter ID', 'County', 'Candidate']
#
# Row read for processing is:  ['12864552', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  1
# Row read for processing is:  ['17444633', 'Marsh', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  2
# Row read for processing is:  ['19330107', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  3
# Row read for processing is:  ['19865775', 'Queen', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  4
# Row read for processing is:  ['11927875', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  5
# Row read for processing is:  ['19014606', 'Marsh', 'Li']
#
# Candidate list index y value =  0
#
# Li != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Li != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Candidate matched!
# Li = Li
#
# Contents of votes list:
#
# Grand total votes =  6
# Row read for processing is:  ['17775191', 'Queen', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  7
# Row read for processing is:  ['14003692', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  8
# Row read for processing is:  ['14255761', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  9
# Row read for processing is:  ['13870173', 'Marsh', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  10
# Row read for processing is:  ['16793141', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  11
# Row read for processing is:  ['10591158', 'Bamoo', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  12
# Row read for processing is:  ['12344763', 'Trandee', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  13
# Row read for processing is:  ['18611011', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  14
# Row read for processing is:  ['17845903', 'Marsh', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  15
# Row read for processing is:  ['12621425', 'Trandee', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  16
# Row read for processing is:  ['14365844', 'Marsh', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  17
# Row read for processing is:  ['13444989', 'Marsh', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  18
# Row read for processing is:  ['19204501', 'Trandee', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  19
# Row read for processing is:  ['10098063', 'Queen', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  20
# Row read for processing is:  ['19843246', 'Marsh', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  21
# Row read for processing is:  ['11509120', 'Marsh', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  22
# Row read for processing is:  ['13402499', 'Marsh', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  23
# Row read for processing is:  ['18138694', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  24
# Row read for processing is:  ['15056703', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  25
# Row read for processing is:  ['12026178', 'Queen', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  26
# Row read for processing is:  ['16667390', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  27
# Row read for processing is:  ['12847422', 'Queen', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  28
# Row read for processing is:  ['10599242', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  29
# Row read for processing is:  ['18558857', 'Queen', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  30
# Row read for processing is:  ['19533707', 'Queen', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  31
# Row read for processing is:  ['13360545', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  32
# Row read for processing is:  ['13212178', 'Queen', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  33
# Row read for processing is:  ['11154929', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  34
# Row read for processing is:  ['19602413', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  35
# Row read for processing is:  ['15405592', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  36
# Row read for processing is:  ['19561790', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  37
# Row read for processing is:  ['17094559', 'Marsh', 'Li']
#
# Candidate list index y value =  0
#
# Li != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Li != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Candidate matched!
# Li = Li
#
# Contents of votes list:
#
# Grand total votes =  38
# Row read for processing is:  ['18233965', 'Marsh', 'Li']
#
# Candidate list index y value =  0
#
# Li != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Li != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Candidate matched!
# Li = Li
#
# Contents of votes list:
#
# Grand total votes =  39
# Row read for processing is:  ['19984144', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  40
# Row read for processing is:  ['16973343', 'Trandee', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  41
# Row read for processing is:  ['17295190', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  42
# Row read for processing is:  ['18554319', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  43
# Row read for processing is:  ['15611748', 'Raffah', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  44
# Row read for processing is:  ['12354752', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  45
# Row read for processing is:  ['19600774', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  46
# Row read for processing is:  ['18121503', 'Bamoo', "O'Tooley"]
#
# Candidate list index y value =  0
#
# O'Tooley != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Candidate matched!
# O'Tooley = O'Tooley
#
# Contents of votes list:
#
# Grand total votes =  47
# Row read for processing is:  ['16911714', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  48
# Row read for processing is:  ['14187424', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  49
# Row read for processing is:  ['12753806', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  50
# Row read for processing is:  ['17120606', 'Trandee', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  51
# Row read for processing is:  ['15925869', 'Marsh', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  52
# Row read for processing is:  ['15716463', 'Queen', 'Khan']
#
# Candidate list index y value =  0
#
# Candidate matched!
# Khan = Khan
#
# Contents of votes list:
#
# Grand total votes =  53
# Row read for processing is:  ['18171107', 'Marsh', 'Correy']
#
# Candidate list index y value =  0
#
# Correy != Khan
#
# y counter =  1
# candidate_lst[y] is:  O'Tooley
#
# Correy != O'Tooley
#
# y counter =  2
# candidate_lst[y] is:  Li
#
# Correy != Li
#
# y counter =  3
# candidate_lst[y] is:  Correy
#
# Candidate matched!
# Correy = Correy
#
# Contents of votes list:
#
# Grand total votes =  54
# ['Khan', "O'Tooley", 'Li', 'Correy']
#
# [36, 1, 3, 14]

# %%
# <insert % calculations here>

# %%
# variables for output file

# %%
# create output file <analysis_PyBank.txt> to store analysis data and 
# store the file in the <analysis> folder
# import os
output_path=os.path.join('analysis','analysis_PyPoll.txt')

# %%
# open the output file and write the analysis data results
with open(output_path, 'w', newline='') as txtfile:
    header1 = 'Election Results \n'
    header2 = '--------------------------------------- \n'
    line1 = 'Total Votes: '
    line_fd = '\n'
    line2 = '--------------------------------------- \n'
    line3 = '<candidate1 variable>:, % variable, votes \n'
    line4 = '<candidate2 variable>:, % variable, votes \n'
    line5 = '<candidate3 variable>:, % variable, votes \n'
    line6 = '--------------------------------------- \n'
    line7 = 'Winner: <candidatewinner variable> \n'
    line8 = '--------------------------------------- \n'
    txtfile.write(header1)
    txtfile.write(header2)
    txtfile.write(line1 + str(total_votes))
    txtfile.write(line_fd)
    txtfile.write(line2)
    txtfile.write(line3)
    txtfile.write(line4)
    txtfile.write(line5)
    txtfile.write(line6)
    txtfile.write(line7)
    txtfile.write(line8)
