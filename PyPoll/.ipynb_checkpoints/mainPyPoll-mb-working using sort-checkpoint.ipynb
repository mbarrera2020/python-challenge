# %%
# main -- for python-challenge PyPoll
import os
import csv

# %%
# setup path for input file location - REMEMBER: remove '1test' from filename -- test data has 250 rows including header
csvpath=os.path.join('Resources','election_data1test.csv')
csvpath
# Out:
# 'Resources\\election_data1test.csv'

# %%
# TEMP - this cell can be deleted -- to be used for testing to read input file
# open & loop through the rows and get total votes by candidates

# create a 'unique' candidate list
candidate_unique = set()

with open(csvpath) as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    
    # Read the header row first (skip this step if there is row header)
    csv_header = next(csvreader)
    print(f"CSV Header: {csv_header}")
    
    sort = sorted(csvreader, key=operator.itemgetter(2)
        
    # TEMP - diplay input file data
    for row in csvreader:
        print(row)
        candidate_unique.add(row[2])
        
print ()
print ("This is the unique candidate set:")        
print (candidate_unique)
print ()

num_candidates = len(list(candidate_unique))
print ("# of candidates:", num_candidates)
print()
# Out:
#   File "<ipython-input-39-a8706b5081db>", line 17
#     for row in csvreader:
#     ^
# SyntaxError: invalid syntax

# %%
# open & loop through the rows and get total votes by candidates

# create candidate list & num votes list
candidate_lst = []

for i in candidate_unique:
    candidate_lst.append(i)
print(candidate_lst)
# Out:
# ['Khan', 'Correy', "O'Tooley", 'Li']

# %%
# open & loop through the rows and get total votes by candidates
import operator   # needed to make sort work

# create votes list & set variables
votes_lst = []

votes_c = 0
votes_total = 0

i = 0
n = num_candidates
print ("# of candidates: ", n)


with open(csvpath) as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    
    # Read the header row first (skip this step if there is row header)
    csv_header = next(csvreader)
    print(f"CSV Header: {csv_header}")
    
    sort = sorted(csvreader, key=operator.itemgetter(2))
        
    for row in sort:
        if i <= n:
            #get candidate name and create list
            print(row[2])
                
#print (candidates_lst)
#print (votes_lst)
# Out:
# # of candidates:  4
# CSV Header: ['Voter ID', 'County', 'Candidate']
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Correy
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Khan
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# Li
# O'Tooley
# O'Tooley
# O'Tooley

# %%
# sort the csv file by Candidate
with open(csvpath) as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
        
    # Read the header row first (skip this step if there is row header)
    csv_header = next(csvreader)
    print(f"CSV Header: {csv_header}")
    print()
    num_rows = len(list(csvreader))
    print("Number of rows: ", num_rows)
    print()
    
    sort = sorted(csvreader, key=operator.itemgetter(2))
    
# set variables
totalvotes = 0 

# create candidate list to store candidates & vote count
candidate_lst =[]


# read file, if candidate name is the same, track votes for candidates
# else put candidate name in list array with candidates total votes
# 
for i in range (num_rows):
    # if i == 2:
        # get the candidate name  candidate = sort.index[2]?
        candidate_lst.append(sort.index[2])
        
        # track # of votes
        totalvotes = totalvotes + 1
        
        i = i + 1
        
print ("Total Votes: ", totalvotes)
print ()

print ("The following are the contents of the candidate lists: ")
print (candidate_lst)
# Out:
# CSV Header: ['Voter ID', 'County', 'Candidate']
#
# Number of rows:  249
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-7386d621ee1b> in <module>
#      26     # if i == 2:
#      27         # get the candidate name  candidate = sort.index[2]?
# ---> 28         candidate_lst.append(sort.index[2])
#      29
#      30         # track # of votes
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
# <insert % calculations here>

# %%
# create output file <analysis_PyBank.txt> to store analysis data and 
# store the file in the <analysis> folder
# import os
output_path=os.path.join('analysis','analysis_PyPoll.txt')

# %%
# open the output file and write the analysis data results
# TEMP -- this is to test writing to a text file
with open(output_path, 'w', newline='') as txtfile:
    header1 = 'Election Results \n'
    header2 = '--------------------------------------- \n'
    line1 = 'Total Votes: \n'
    line2 = '--------------------------------------- \n'
    line3 = '<candidate1 variable>:, % variable, votes \n'
    line4 = '<candidate2 variable>:, % variable, votes \n'
    line5 = '<candidate3 variable>:, % variable, votes \n'
    line6 = '--------------------------------------- \n'
    line7 = 'Winner: <candidatewinner variable> \n'
    line8 = '--------------------------------------- \n'
    txtfile.write(header1)
    txtfile.write(header2)
    txtfile.write(line1)
    txtfile.write(line2)
    txtfile.write(line3)
    txtfile.write(line4)
    txtfile.write(line5)
    txtfile.write(line6)
    txtfile.write(line7)
    txtfile.write(line8)
